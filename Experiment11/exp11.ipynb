# %%
# Step 1: Import Libraries
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import imdb

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, LSTM, GRU, Dense
from tensorflow.keras.preprocessing.sequence import pad_sequences
import matplotlib.pyplot as plt
# Step 2: Load and Preprocess Dataset
(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=10000)
max_len = 200
X_train = pad_sequences(X_train, maxlen=max_len)
X_test = pad_sequences(X_test, maxlen=max_len)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense

def build_vanilla_rnn():
    model = Sequential([
        Embedding(input_dim=10000, output_dim=32, input_length=200),
        SimpleRNN(32),
        Dense(1, activation='sigmoid')
    ])
    
    model.compile(
        loss='binary_crossentropy',
        optimizer='adam',
        metrics=['accuracy']
    )
    
    return model


# Build model
rnn_model = build_vanilla_rnn()

# Train model
rnn_history = rnn_model.fit(
    X_train,
    y_train,
    epochs=5,
    batch_size=64,
    validation_split=0.2
)

# Evaluate model
rnn_loss, rnn_acc = rnn_model.evaluate(X_test, y_test)

print(f'Vanilla RNN Test Accuracy: {rnn_acc:.4f}')
# Out:
# C:\Users\kulka\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\core\embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 28s 75ms/step - accuracy: 0.6136 - loss: 0.6473 - val_accuracy: 0.5968 - val_loss: 0.6583
# Epoch 2/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 22s 72ms/step - accuracy: 0.7517 - loss: 0.5104 - val_accuracy: 0.7586 - val_loss: 0.5061
# Epoch 3/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 42s 76ms/step - accuracy: 0.8665 - loss: 0.3176 - val_accuracy: 0.8180 - val_loss: 0.4255
# Epoch 4/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 22s 70ms/step - accuracy: 0.9402 - loss: 0.1684 - val_accuracy: 0.8240 - val_loss: 0.4598
# Epoch 5/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 22s 70ms/step - accuracy: 0.9740 - loss: 0.0836 - val_accuracy: 0.8188 - val_loss: 0.5379
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.8165 - loss: 0.5459
# Vanilla RNN Test Accuracy: 0.8165

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

def build_lstm():
    model = Sequential([
        Embedding(input_dim=10000, output_dim=32, input_length=200),
        LSTM(32),
        Dense(1, activation='sigmoid')
    ])
    
    model.compile(
        loss='binary_crossentropy',
        optimizer='adam',
        metrics=['accuracy']
    )
    
    return model


# Build model
lstm_model = build_lstm()

# Train model
lstm_history = lstm_model.fit(
    X_train,
    y_train,
    epochs=5,
    batch_size=64,
    validation_split=0.2
)

# Evaluate model
lstm_loss, lstm_acc = lstm_model.evaluate(X_test, y_test)

print(f'LSTM Test Accuracy: {lstm_acc:.4f}')
# Out:
# Epoch 1/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 43s 121ms/step - accuracy: 0.7779 - loss: 0.4509 - val_accuracy: 0.8578 - val_loss: 0.3517
# Epoch 2/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 36s 114ms/step - accuracy: 0.9010 - loss: 0.2515 - val_accuracy: 0.8664 - val_loss: 0.3113
# Epoch 3/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 112ms/step - accuracy: 0.9342 - loss: 0.1784 - val_accuracy: 0.8702 - val_loss: 0.3143
# Epoch 4/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 38s 121ms/step - accuracy: 0.9514 - loss: 0.1375 - val_accuracy: 0.8704 - val_loss: 0.3770
# Epoch 5/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 36s 114ms/step - accuracy: 0.9625 - loss: 0.1110 - val_accuracy: 0.8694 - val_loss: 0.4111
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 24s 31ms/step - accuracy: 0.8588 - loss: 0.4320
# LSTM Test Accuracy: 0.8588

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, GRU, Dense

def build_gru():
    model = Sequential([
        Embedding(input_dim=10000, output_dim=32, input_length=200),
        GRU(32),
        Dense(1, activation='sigmoid')
    ])
    
    model.compile(
        loss='binary_crossentropy',
        optimizer='adam',
        metrics=['accuracy']
    )
    
    return model


# Build model
gru_model = build_gru()

# Train model
gru_history = gru_model.fit(
    X_train,
    y_train,
    epochs=5,
    batch_size=64,
    validation_split=0.2
)

# Evaluate model
gru_loss, gru_acc = gru_model.evaluate(X_test, y_test)

print(f'GRU Test Accuracy: {gru_acc:.4f}')
# Out:
# Epoch 1/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 34s 89ms/step - accuracy: 0.7577 - loss: 0.4772 - val_accuracy: 0.8488 - val_loss: 0.3577
# Epoch 2/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 32s 60ms/step - accuracy: 0.8916 - loss: 0.2765 - val_accuracy: 0.8688 - val_loss: 0.3259
# Epoch 3/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 18s 58ms/step - accuracy: 0.9195 - loss: 0.2101 - val_accuracy: 0.8616 - val_loss: 0.3411
# Epoch 4/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 18s 59ms/step - accuracy: 0.9331 - loss: 0.1809 - val_accuracy: 0.8634 - val_loss: 0.3470
# Epoch 5/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 19s 59ms/step - accuracy: 0.9474 - loss: 0.1450 - val_accuracy: 0.8600 - val_loss: 0.3936
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.8553 - loss: 0.4049
# GRU Test Accuracy: 0.8553

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, GRU, Dense

def build_gru():
    model = Sequential([
        Embedding(input_dim=10000, output_dim=32, input_length=200),
        GRU(32),
        Dense(1, activation='sigmoid')
    ])
    
    model.compile(
        loss='binary_crossentropy',
        optimizer='adam',
        metrics=['accuracy']
    )
    
    return model   # ✅ must be inside function


# Outside function (no indentation)
gru_model = build_gru()

gru_history = gru_model.fit(
    X_train,
    y_train,
    epochs=5,
    batch_size=64,
    validation_split=0.2
)

gru_loss, gru_acc = gru_model.evaluate(X_test, y_test)

print(f'GRU Test Accuracy: {gru_acc:.4f}')
# Out:
# Epoch 1/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 23s 66ms/step - accuracy: 0.7490 - loss: 0.4825 - val_accuracy: 0.8530 - val_loss: 0.3434
# Epoch 2/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 30s 97ms/step - accuracy: 0.8901 - loss: 0.2737 - val_accuracy: 0.8570 - val_loss: 0.3397
# Epoch 3/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 26s 82ms/step - accuracy: 0.9235 - loss: 0.2029 - val_accuracy: 0.8538 - val_loss: 0.4549
# Epoch 4/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 37s 68ms/step - accuracy: 0.9387 - loss: 0.1655 - val_accuracy: 0.8648 - val_loss: 0.3552
# Epoch 5/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 27s 86ms/step - accuracy: 0.9554 - loss: 0.1283 - val_accuracy: 0.8538 - val_loss: 0.4349
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.8485 - loss: 0.4390
# GRU Test Accuracy: 0.8485

# %%
# Plot accuracy comparison
plt.figure(figsize=(14, 5))
plt.subplot(1, 2, 1)
plt.plot(rnn_history.history['val_accuracy'], label='Vanilla RNN')
plt.plot(lstm_history.history['val_accuracy'], label='LSTM')
plt.plot(gru_history.history['val_accuracy'], label='GRU')
plt.title('Validation Accuracy Comparison')
plt.xlabel('Epoch'); plt.ylabel('Accuracy')
plt.legend()
plt.subplot(1, 2, 2)
plt.plot(rnn_history.history['val_loss'], label='Vanilla RNN')
plt.plot(lstm_history.history['val_loss'], label='LSTM')
plt.plot(gru_history.history['val_loss'], label='GRU')
plt.title('Validation Loss Comparison')
plt.xlabel('Epoch'); plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('rnn_comparison.png', dpi=150)
plt.show()
